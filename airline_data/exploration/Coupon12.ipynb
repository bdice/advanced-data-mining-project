# %% [markdown]
# # Exploratory Data Analysis 12
# Plotting first-order communities found by InfoMap, except with the same color scheme for comparison with the overlaid HON communities.

# %%
import matplotlib
#matplotlib.use('Agg')
import matplotlib.colors as mcolors
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import pandas as pd
import cartopy.crs as ccrs
import cartopy.io.shapereader as shpreader
import signac
from util import fetch_geodata

project = signac.get_project()
job = project.find_jobs({"year": 2011, "quarter": 1}).next()

# %%
paths = pd.read_csv(job.fn('first_order_infomap.tree'), sep=' ', header=None, skiprows=2, names=['path', 'flow', 'ID', 'node'])
paths['path'] = paths['path'].apply(lambda x: tuple(map(int, x.split(':'))))
paths = paths.sort_values('path')
iatas = pd.read_csv(job.fn('airport_codes.csv'))
iatas['ID'] = pd.to_numeric(iatas['ID'])
iatas = iatas.set_index('ID')
airports = pd.merge(iatas, fetch_geodata(), left_on='IATA', right_index=True)
paths = pd.merge(paths, airports, left_on='ID', right_index=True)
paths = paths.sort_values('path')
paths
# Out:
# Reading airport geodata...
#             path          flow     ID  node IATA  \
# 0      (1, 1, 1)  6.592530e-02  10397    29  ATL
# 1      (1, 1, 2)  4.533480e-02  13930   318  ORD
# 2      (1, 1, 3)  4.367130e-02  11292   115  DEN
# 3      (1, 1, 4)  4.258200e-02  11298   116  DFW
# 4      (1, 1, 5)  4.035980e-02  11057    91  CLT
# 5      (1, 1, 6)  3.169800e-02  14107   332  PHX
# 6      (1, 1, 7)  2.836330e-02  12892   239  LAX
# 7      (1, 1, 8)  2.545450e-02  12266   204  IAH
# 8      (1, 1, 9)  2.453330e-02  13487   302  MSP
# 9     (1, 1, 10)  2.397230e-02  11433   124  DTW
# 10    (1, 1, 11)  2.254880e-02  14100   331  PHL
# 11    (1, 1, 12)  2.194510e-02  12889   237  LAS
# 12    (1, 1, 13)  2.051940e-02  14771   387  SFO
# 13    (1, 1, 14)  1.958410e-02  13204   272  MCO
# 14    (1, 1, 15)  1.900010e-02  14747   385  SEA
# 15    (1, 1, 16)  1.804690e-02  14869   397  SLC
# 16    (1, 1, 17)  1.486530e-02  10821    70  BWI
# 17    (1, 1, 18)  1.388190e-02  12953   249  LGA
# 18    (1, 1, 19)  1.379340e-02  10721    57  BOS
# 19    (1, 1, 20)  1.348980e-02  11278   113  DCA
# 20    (1, 1, 21)  1.302590e-02  11618   144  EWR
# 21    (1, 1, 22)  1.300740e-02  12264   202  IAD
# 22    (1, 1, 23)  1.283910e-02  11697   153  FLL
# 23    (1, 1, 24)  1.195990e-02  15304   421  TPA
# 24    (1, 1, 25)  1.194230e-02  13232   275  MDW
# 25    (1, 1, 26)  1.145120e-02  12478   225  JFK
# 26    (1, 1, 27)  1.126900e-02  14679   372  SAN
# 27    (1, 1, 28)  1.053290e-02  13303   284  MIA
# 28    (1, 1, 29)  1.052220e-02  13244   277  MEM
# 29    (1, 1, 30)  9.674690e-03  15016   408  STL
# ..           ...           ...    ...   ...  ...
# 388  (1, 1, 389)  2.440950e-06  12185   192  HON
# 389  (1, 1, 390)  2.324710e-06  10925    76  CDR
# 390  (1, 1, 391)  2.248360e-06  14875   398  SLK
# 391  (1, 1, 392)  1.764770e-06  11908   169  GGW
# 392  (1, 1, 393)  1.511060e-06  11856   162  GBD
# 393  (1, 1, 394)  1.511060e-06  14237   344  PRC
# 394  (1, 1, 395)  1.502000e-06  13182   265  MBL
# 395  (1, 1, 396)  1.420020e-06  14306   351  PVC
# 396  (1, 1, 397)  1.399470e-06  12245   199  HVR
# 397  (1, 1, 398)  1.394830e-06  10221    15  AIA
# 398  (1, 1, 399)  1.394830e-06  13375   291  MLS
# 399  (1, 1, 400)  1.288800e-06  13862   314  OLF
# 400  (1, 1, 401)  1.277420e-06  14943   403  SOW
# 401  (1, 1, 402)  1.048630e-06  11085    95  CNM
# 402  (1, 1, 403)  1.047120e-06  10216    14  AHN
# 403  (1, 1, 404)  1.039850e-06  12412   220  IWD
# 404  (1, 1, 405)  1.033950e-06  12297   207  IGM
# 405  (1, 1, 406)  8.155990e-07  10266    18  ALM
# 406  (1, 1, 407)  8.155060e-07  11879   165  GDV
# 407  (1, 1, 408)  7.001980e-07  13128   261  LWT
# 408  (1, 1, 409)  5.825710e-07  15051   414  SVC
# 409  (1, 1, 410)  3.498500e-07  13348   288  MKL
# 410  (1, 1, 411)  3.446490e-07  13194   267  MCE
# 411  (1, 1, 412)  2.327220e-07  15601   438  VIS
# 412  (1, 1, 413)  2.325100e-07  11531   134  ELD
# 413  (1, 1, 414)  1.784950e-07  11615   142  EWB
# 414  (1, 1, 415)  1.165140e-07  12177   190  HOB
# 415  (1, 1, 416)  1.160990e-07  12319   208  ILE
# 416  (1, 1, 417)  1.151690e-07  12917   245  LCK
# 417  (1, 1, 418)  0.000000e+00  10744    62  BRL
#
#                                                   name         lon        lat
# 0     Hartsfield Jackson Atlanta International Airport  -84.428101  33.636700
# 1                 Chicago O'Hare International Airport  -87.904800  41.978600
# 2                         Denver International Airport -104.672997  39.861698
# 3              Dallas Fort Worth International Airport  -97.038002  32.896801
# 4              Charlotte Douglas International Airport  -80.943100  35.214001
# 5             Phoenix Sky Harbor International Airport -112.012001  33.434299
# 6                    Los Angeles International Airport -118.407997  33.942501
# 7         George Bush Intercontinental Houston Airport  -95.341400  29.984400
# 8    Minneapolis-St Paul International/Wold-Chamber...  -93.221802  44.882000
# 9            Detroit Metropolitan Wayne County Airport  -83.353401  42.212399
# 10                  Philadelphia International Airport  -75.241096  39.871899
# 11                      McCarran International Airport -115.152000  36.080101
# 12                 San Francisco International Airport -122.375000  37.618999
# 13                       Orlando International Airport  -81.308998  28.429399
# 14                Seattle Tacoma International Airport -122.308998  47.449001
# 15                Salt Lake City International Airport -111.977997  40.788399
# 16   Baltimore/Washington International Thurgood Ma...  -76.668297  39.175400
# 17                                  La Guardia Airport  -73.872597  40.777199
# 18   General Edward Lawrence Logan International Ai...  -71.005203  42.364300
# 19           Ronald Reagan Washington National Airport  -77.037697  38.852100
# 20                Newark Liberty International Airport  -74.168701  40.692501
# 21             Washington Dulles International Airport  -77.455803  38.944500
# 22     Fort Lauderdale Hollywood International Airport  -80.152702  26.072599
# 23                         Tampa International Airport  -82.533203  27.975500
# 24                Chicago Midway International Airport  -87.752403  41.785999
# 25                John F Kennedy International Airport  -73.778900  40.639801
# 26                     San Diego International Airport -117.190002  32.733601
# 27                         Miami International Airport  -80.290604  25.793200
# 28                       Memphis International Airport  -89.976700  35.042400
# 29              St Louis Lambert International Airport  -90.370003  38.748697
# ..                                                 ...         ...        ...
# 388                             Huron Regional Airport  -98.228500  44.385201
# 389                          Chadron Municipal Airport -103.095001  42.837601
# 390                        Adirondack Regional Airport  -74.206200  44.385300
# 391          Wokal Field Glasgow International Airport -106.614998  48.212502
# 392                       Great Bend Municipal Airport  -98.859200  38.344299
# 393                               Ernest A. Love Field -112.419998  34.654499
# 394                        Manistee Co Blacker Airport  -86.246902  44.272400
# 395                     Provincetown Municipal Airport  -70.221397  42.071899
# 396                          Havre City County Airport -109.762001  48.542999
# 397                         Alliance Municipal Airport -102.804001  42.053200
# 398                                  Frank Wiley Field -105.886002  46.428001
# 399                                L M Clayton Airport -105.574997  48.094501
# 400                          Show Low Regional Airport -110.005997  34.265499
# 401                           Cavern City Air Terminal -104.263000  32.337502
# 402                            Athens Ben Epps Airport  -83.326302  33.948601
# 403                        Gogebic Iron County Airport  -90.131401  46.527500
# 404                                    Kingman Airport -113.938004  35.259499
# 405            Alamogordo White Sands Regional Airport -105.990997  32.839901
# 406                           Dawson Community Airport -104.806999  47.138699
# 407                        Lewistown Municipal Airport -109.467003  47.049301
# 408                               Grant County Airport -108.155998  32.636501
# 409                    McKellar-Sipes Regional Airport  -88.915604  35.599899
# 410                     Merced Regional Macready Field -120.514000  37.284698
# 411                          Visalia Municipal Airport -119.392998  36.318699
# 412           South Arkansas Regional At Goodwin Field  -92.813301  33.221001
# 413                       New Bedford Regional Airport  -70.956902  41.676102
# 414                        Lea County Regional Airport -103.217003  32.687500
# 415                                      Skylark Field  -97.686501  31.085800
# 416                 Rickenbacker International Airport  -82.927803  39.813801
# 417                    Southeast Iowa Regional Airport  -91.125504  40.783199
#
# [401 rows x 8 columns]

# %%
def plot_community(paths, community=None):
    print('Generating plot...')
    fig = plt.figure(figsize=(6, 4), dpi=400)
    ax = fig.add_axes([0, 0, 1, 1], projection=ccrs.LambertConformal())
    ax.set_extent([-128, -64, 22, 49], ccrs.Geodetic())

    shapename = 'admin_1_states_provinces_shp'
    states_shp = shpreader.natural_earth(resolution='110m',
                                         category='cultural', name=shapename)

    ax.background_patch.set_visible(False)
    ax.outline_patch.set_visible(False)
    plt.title('Communit{} from First-Order Network ({}Q{})'.format(
        'ies' if community is None else 'y ' + str(community),
        job.sp.year, job.sp.quarter))

    def colorize_state(geometry):
        facecolor = (0.9375, 0.9375, 0.8594)
        return {'facecolor': facecolor, 'edgecolor': 'black'}

    ax.add_geometries(
        shpreader.Reader(states_shp).geometries(),
        ccrs.PlateCarree(),
        styler=colorize_state)

    xs = paths.lon.values
    ys = paths.lat.values
    colors = (matplotlib.cm.get_cmap('tab10')(0),) * len(xs)
    sizes = 10000*paths.flow.values
    

    dots = ax.scatter(xs, ys, transform=ccrs.PlateCarree(), c=colors, s=sizes, alpha=0.8, zorder=10)

    top_n = paths.sort_values('flow', ascending=False).head(20).index
    for row in paths.loc[top_n].itertuples():
        ax.annotate(row.IATA, (row.lon, row.lat), xycoords=ccrs.PlateCarree()._as_mpl_transform(ax),
                    fontsize=10,  # 40*row.flow**0.2,
                    zorder=11, ha='center', va='center')
    plt.show()
    plt.close()

# %%
def get_community(paths, community_path):
    if len(community_path) == 3:
        left = tuple([*community_path[:-1], community_path[-1]-1])
        right = tuple([*community_path[:-1], community_path[-1]+1])
    else:
        left = tuple([*community_path, *(-1,)*(3-len(community_path))])
        right = tuple([*community_path[:-1], community_path[-1]+1, *(0,)*(3-len(community_path))])
    return paths[paths.path.between(left, right)]

# %%
for community in paths.path.apply(lambda x: x[:2]).unique():
    data = get_community(paths, community)
    flow = sum(data.flow)
    print('{} {}'.format(community, flow))
    plot_community(data, community=community)
# Out:
# (1, 1) 0.9820907732220002
# Generating plot...
